# %%
from matplotlib import pyplot as plt
import sys
import os
import glob
# %load_ext autoreload
# %autoreload 2
sys.path.append(os.path.join('../src'))
from utils.definitions import ROOT_DIR, DATA_DIR
from utils.pfm_utils import get_np_from_pfm, get_img_and_depth
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_dir = str(DATA_DIR) + '/geoPose3K/'
file_list = os.listdir(data_dir)
depth = loader.load_pfm(dir+'distance_crop1.pfm')
depth2 = loader.load_pfm(dir+'distance_crop2.pfm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ed953735286a> in <module>
#       1 data_dir = str(DATA_DIR) + '/geoPose3K/'
#       2 file_list = os.listdir(data_dir)
# ----> 3 depth = loader.load_pfm(dir+'distance_crop1.pfm')
#       4 depth2 = loader.load_pfm(dir+'distance_crop2.pfm')
#       5
#
# NameError: name 'loader' is not defined

# %%
folder = os.listdir(data_dir)[1]
folder_name = os.path.join(data_dir,folder)
print(folder_name)
img, depth = get_img_and_depth(folder_name)
# Out:
# /media/ariel/6EEE7AB0EE7A7067/Users/Ariel/Documents/DS הכשרה_/15. MDE with laser reference point/laser-mde/data/geoPose3K/28488116812_f5a57ca0f6_k

# %%
def print_images(num=1):
    for i in range(num):
        folder = os.listdir(data_dir)[50+i]
        folder_name = os.path.join(data_dir,folder)
#         print(folder_name)
        img, depth = get_img_and_depth(folder_name)
        plt.imshow(img)
        plt.title(img.shape)
        plt.show()
        plt.imshow(depth)
        plt.title(depth.shape)
        plt.show()
        print(img.shape[1]/img.shape[0],depth.shape[1]/depth.shape[0])

# %%
print_images(2)
# plt.savefig(data_dir+'depth.jpg', bbox_inches='tight')
# Out:
# 1.4970760233918128 1.346086956521739
# 1.3333333333333333 1.175

# %%
img = plt.imread(dir+'photo.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-3f2c0d6dfee4> in <module>
# ----> 1 img = plt.imread(dir+'photo.jpg')
#       2
#
# TypeError: unsupported operand type(s) for +: 'builtin_function_or_method' and 'str'

# %%
print(depth.shape, img.shape)
# Out:
# (593, 775) (1536, 2048, 3)
